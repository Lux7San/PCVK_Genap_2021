# %% [markdown]
# <a href="https://colab.research.google.com/github/Lux7San/PCVK_Genap_2021/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##***Langkah (Step) 1 :***

# %%
from google.colab import drive

# Accesing My Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# code : 4/1AY0e-g7om9O27A085XMnRqPLlhB5ORmWiaorPLC8dOGI6P334mdlESUBUlE

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kucing.jpg')
plt.imshow(img)          #perhatikan hasilnya adalah citra dgn channel warna BGR
